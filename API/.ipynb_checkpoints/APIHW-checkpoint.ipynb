# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * It is very apparent in this data that the latitude is very strongly correlated with the max temperature in any given city. More specifically, there is a positive correlation between the absolute value of the latitude and the max temperature, meaning as you get further away from the equator, the max temperature increases.
# * There seems to be no particular relationship between city latitude and Humidity, with the exception of a dearth of low humidity cities within 20 degrees of the equator. Once you get 20 degrees north or south of the equator, the range of humidity ranges from 40 percent to 100 percent without a strong relationship between latitude and humidity.
# * Continents do not seem to very strongly correlate with any of the factors tested here, with the exception of the relationships that already exist with Latitude.
# * The data collected for clou cover is discrete, rather than continuous, and as such, it is not clear that the data would demonstrate as strong a relationship as the other factors might. In any case, the data presented do not seem to correlate between cloud cover and latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.font_manager import FontProperties
import pandas as pd
import numpy as np
import requests
import datetime
import time
from pprint import pprint

#Import Date of Pull
now =datetime.datetime.now()
date = now.strftime("%m/%d/%Y")

# Import API key
from api_keys import api_key as key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
outputfile = "output/cities.csv"

#Import continent converting csv and make datafram. 
#This will allow the continents to be displayed in different colors on the graph
cont = pd.read_csv("continent.csv", keep_default_na=False)
cont = cont.rename(index=str, columns={'iso 3166 country':'Country', 'continent code': 'Continent'})

# define units as imperial
units = 'imperial'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
pprint(len(cities))
# Out:
# 621

# %%
#Define the base query url
qurl = "http://api.openweathermap.org/data/2.5/weather?appid=" + key + "&units=" + units + "&q="
# define lists for the variables tracked and the counter for the record count
humid = []
cloud =[]
wind = []
lat = []
lng = []
temp = []
citi = []
country = []
count = 1

# Loop through the city list and collect the variables needed.
# Also add the Error processing to print that it is skipping a city.
for city in cities:
    try:
        resp = requests.get(qurl + city).json()
        lat.append(resp['coord']['lat'])
        lng.append(resp['coord']['lon'])
        temp.append(resp['main']['temp_max'])
        humid.append(resp['main']['humidity'])
        cloud.append(resp['clouds']['all'])
        wind.append(resp['wind']['speed'])
        citi.append(resp['name'])
        country.append(resp['sys']['country'])
        print(f"Processing Record {count} for {city}")
        count = count + 1
    except KeyError:
        print("City not found, skipping")
        continue
# This delay line is probably unnecessary, but it is included so that the API doesn't get locked out.    
    time.sleep(.01)
# Out:
# Processing Record 1 for sioux lookout
# Processing Record 2 for celles
# Processing Record 3 for beloha
# City not found, skipping
# Processing Record 4 for nikolskoye
# Processing Record 5 for ushuaia
# Processing Record 6 for thinadhoo
# City not found, skipping
# Processing Record 7 for asahikawa
# Processing Record 8 for faanui
# Processing Record 9 for rocha
# Processing Record 10 for mbanza-ngungu
# Processing Record 11 for vincennes
# Processing Record 12 for port elizabeth
# Processing Record 13 for saint-philippe
# Processing Record 14 for souillac
# Processing Record 15 for jamestown
# City not found, skipping
# Processing Record 16 for merauke
# Processing Record 17 for albany
# Processing Record 18 for trairi
# Processing Record 19 for isla mujeres
# Processing Record 20 for mahebourg
# Processing Record 21 for livingstonia
# City not found, skipping
# Processing Record 22 for bredasdorp
# Processing Record 23 for pevek
# Processing Record 24 for hermanus
# Processing Record 25 for yellowknife
# Processing Record 26 for ekhabi
# Processing Record 27 for vaini
# Processing Record 28 for qaqortoq
# Processing Record 29 for georgetown
# Processing Record 30 for bintulu
# Processing Record 31 for saskylakh
# Processing Record 32 for cape town
# Processing Record 33 for saint george
# Processing Record 34 for rikitea
# Processing Record 35 for kahului
# Processing Record 36 for udala
# Processing Record 37 for constitucion
# Processing Record 38 for college
# Processing Record 39 for punta arenas
# Processing Record 40 for bambous virieux
# Processing Record 41 for jardim
# Processing Record 42 for kodiak
# Processing Record 43 for new norfolk
# City not found, skipping
# Processing Record 44 for dabola
# Processing Record 45 for thompson
# Processing Record 46 for villanueva de cordoba
# Processing Record 47 for arraial do cabo
# Processing Record 48 for port blair
# City not found, skipping
# Processing Record 49 for clyde river
# Processing Record 50 for brae
# Processing Record 51 for carnarvon
# Processing Record 52 for busselton
# City not found, skipping
# Processing Record 53 for marsh harbour
# Processing Record 54 for tual
# Processing Record 55 for port macquarie
# Processing Record 56 for east london
# Processing Record 57 for cotonou
# Processing Record 58 for isla vista
# Processing Record 59 for erzin
# Processing Record 60 for ribeira grande
# Processing Record 61 for mataura
# Processing Record 62 for jinchang
# Processing Record 63 for bluff
# Processing Record 64 for yerbogachen
# Processing Record 65 for atar
# Processing Record 66 for maceio
# Processing Record 67 for vostok
# Processing Record 68 for porto novo
# Processing Record 69 for uthal
# Processing Record 70 for cherskiy
# Processing Record 71 for nome
# Processing Record 72 for barrow
# Processing Record 73 for atuona
# City not found, skipping
# Processing Record 74 for wanning
# Processing Record 75 for hilo
# Processing Record 76 for bubaque
# Processing Record 77 for kidal
# Processing Record 78 for morondava
# Processing Record 79 for avera
# Processing Record 80 for sao filipe
# Processing Record 81 for khatanga
# Processing Record 82 for maldonado
# Processing Record 83 for huilong
# Processing Record 84 for tiarei
# Processing Record 85 for harrison
# Processing Record 86 for springfield
# Processing Record 87 for tiksi
# Processing Record 88 for victoria
# Processing Record 89 for lebu
# Processing Record 90 for belmonte
# Processing Record 91 for bathurst
# City not found, skipping
# Processing Record 92 for katsuura
# Processing Record 93 for port alfred
# Processing Record 94 for wieliczka
# City not found, skipping
# Processing Record 95 for mar del plata
# Processing Record 96 for tasiilaq
# Processing Record 97 for fort nelson
# Processing Record 98 for dong xoai
# Processing Record 99 for chuy
# Processing Record 100 for churapcha
# Processing Record 101 for portland
# Processing Record 102 for chupa
# Processing Record 103 for kulebaki
# Processing Record 104 for hun
# Processing Record 105 for saint anthony
# Processing Record 106 for kudahuvadhoo
# Processing Record 107 for kapaa
# Processing Record 108 for novosheshminsk
# Processing Record 109 for cockburn town
# Processing Record 110 for klyuchevskiy
# Processing Record 111 for richards bay
# Processing Record 112 for kaputa
# Processing Record 113 for banff
# Processing Record 114 for huarmey
# Processing Record 115 for belaya gora
# Processing Record 116 for yulara
# Processing Record 117 for noumea
# City not found, skipping
# Processing Record 118 for kirakira
# Processing Record 119 for puerto ayora
# Processing Record 120 for presidente medici
# City not found, skipping
# Processing Record 121 for lulea
# Processing Record 122 for moen
# Processing Record 123 for vestmannaeyjar
# Processing Record 124 for khovu-aksy
# Processing Record 125 for hobart
# Processing Record 126 for voyvozh
# City not found, skipping
# Processing Record 127 for jumla
# Processing Record 128 for hamilton
# Processing Record 129 for zhigansk
# Processing Record 130 for soyo
# Processing Record 131 for butaritari
# Processing Record 132 for paamiut
# Processing Record 133 for cidreira
# Processing Record 134 for salalah
# Processing Record 135 for fortuna
# Processing Record 136 for airai
# Processing Record 137 for sumenep
# Processing Record 138 for marrakesh
# Processing Record 139 for aykhal
# Processing Record 140 for miracema do tocantins
# Processing Record 141 for moron
# Processing Record 142 for zorritos
# Processing Record 143 for saldanha
# Processing Record 144 for porbandar
# Processing Record 145 for alofi
# Processing Record 146 for klyuchi
# City not found, skipping
# Processing Record 147 for kedrovyy
# City not found, skipping
# City not found, skipping
# Processing Record 148 for ngunguru
# City not found, skipping
# Processing Record 149 for komsomolskiy
# Processing Record 150 for pocone
# Processing Record 151 for klaksvik
# Processing Record 152 for longyearbyen
# Processing Record 153 for mahibadhoo
# Processing Record 154 for antofagasta
# Processing Record 155 for westport
# Processing Record 156 for ust-koksa
# Processing Record 157 for broome
# Processing Record 158 for severo-kurilsk
# Processing Record 159 for vanino
# Processing Record 160 for talnakh
# Processing Record 161 for sitka
# Processing Record 162 for edd
# Processing Record 163 for prince rupert
# Processing Record 164 for dikson
# Processing Record 165 for tiznit
# Processing Record 166 for coruripe
# Processing Record 167 for upernavik
# Processing Record 168 for tuy hoa
# Processing Record 169 for rio grande
# City not found, skipping
# Processing Record 170 for ulladulla
# Processing Record 171 for sao jose da coroa grande
# Processing Record 172 for saryg-sep
# Processing Record 173 for muriwai beach
# Processing Record 174 for ilulissat
# Processing Record 175 for mayo
# Processing Record 176 for siuna
# Processing Record 177 for seoul
# Processing Record 178 for codrington
# Processing Record 179 for buala
# Processing Record 180 for guaymas
# City not found, skipping
# Processing Record 181 for sant feliu de guixols
# Processing Record 182 for tigil
# City not found, skipping
# Processing Record 183 for sungaipenuh
# Processing Record 184 for pidvynohradiv
# Processing Record 185 for genhe
# City not found, skipping
# Processing Record 186 for hithadhoo
# Processing Record 187 for jalu
# Processing Record 188 for baker city
# Processing Record 189 for luwuk
# Processing Record 190 for sarkand
# Processing Record 191 for lompoc
# Processing Record 192 for tuktoyaktuk
# Processing Record 193 for srednekolymsk
# Processing Record 194 for qaanaaq
# Processing Record 195 for balkanabat
# Processing Record 196 for kurilsk
# Processing Record 197 for lhokseumawe
# Processing Record 198 for saint-francois
# Processing Record 199 for bethel
# Processing Record 200 for labuhan
# Processing Record 201 for isangel
# Processing Record 202 for port hardy
# Processing Record 203 for sur
# Processing Record 204 for kamina
# Processing Record 205 for juneau
# Processing Record 206 for cabo san lucas
# Processing Record 207 for kawalu
# City not found, skipping
# Processing Record 208 for roma
# Processing Record 209 for mtinko
# Processing Record 210 for lesosibirsk
# Processing Record 211 for the pas
# Processing Record 212 for los llanos de aridane
# Processing Record 213 for devonport
# Processing Record 214 for verkhoyansk
# Processing Record 215 for laguna
# Processing Record 216 for chernyshevskiy
# Processing Record 217 for umm kaddadah
# Processing Record 218 for provideniya
# Processing Record 219 for gisors
# Processing Record 220 for asuncion
# Processing Record 221 for saint-augustin
# Processing Record 222 for szentgotthard
# Processing Record 223 for bilibino
# Processing Record 224 for caravelas
# Processing Record 225 for tautira
# Processing Record 226 for shaowu
# Processing Record 227 for kaitangata
# Processing Record 228 for altamira
# Processing Record 229 for ilam
# Processing Record 230 for coquimbo
# Processing Record 231 for surt
# Processing Record 232 for manavalakurichi
# City not found, skipping
# Processing Record 233 for san policarpo
# Processing Record 234 for palmer
# Processing Record 235 for debre tabor
# City not found, skipping
# Processing Record 236 for dingle
# Processing Record 237 for buraydah
# Processing Record 238 for hokitika
# Processing Record 239 for salekhard
# Processing Record 240 for hammerfest
# Processing Record 241 for boda
# Processing Record 242 for kilifi
# Processing Record 243 for bull savanna
# Processing Record 244 for norman wells
# Processing Record 245 for uglerodovskiy
# Processing Record 246 for kananga
# Processing Record 247 for huaihua
# Processing Record 248 for lockport
# City not found, skipping
# Processing Record 249 for la tuque
# Processing Record 250 for faya
# Processing Record 251 for minbu
# Processing Record 252 for namanyere
# Processing Record 253 for sisophon
# Processing Record 254 for shenjiamen
# Processing Record 255 for hasaki
# Processing Record 256 for shetpe
# Processing Record 257 for benoy
# Processing Record 258 for acapulco
# Processing Record 259 for vila velha
# Processing Record 260 for talakan
# Processing Record 261 for reyes
# Processing Record 262 for katobu
# City not found, skipping
# Processing Record 263 for vila franca do campo
# Processing Record 264 for payo
# Processing Record 265 for pareora
# Processing Record 266 for wewak
# Processing Record 267 for peterhead
# Processing Record 268 for talas
# Processing Record 269 for americus
# Processing Record 270 for klamath falls
# Processing Record 271 for torbay
# Processing Record 272 for castro
# City not found, skipping
# Processing Record 273 for teguldet
# Processing Record 274 for moranbah
# Processing Record 275 for kuusamo
# Processing Record 276 for lucapa
# Processing Record 277 for eureka
# Processing Record 278 for abu dhabi
# Processing Record 279 for sembakung
# Processing Record 280 for sao felix do xingu
# Processing Record 281 for poum
# Processing Record 282 for hit
# Processing Record 283 for gravdal
# Processing Record 284 for lata
# Processing Record 285 for haimen
# Processing Record 286 for monrovia
# Processing Record 287 for kruisfontein
# Processing Record 288 for mecca
# Processing Record 289 for port lincoln
# Processing Record 290 for dawlatabad
# Processing Record 291 for aklavik
# Processing Record 292 for cayenne
# Processing Record 293 for northam
# Processing Record 294 for lavrentiya
# Processing Record 295 for winneba
# City not found, skipping
# Processing Record 296 for lewiston
# Processing Record 297 for beringovskiy
# Processing Record 298 for bathsheba
# Processing Record 299 for port-gentil
# Processing Record 300 for nanortalik
# Processing Record 301 for la rioja
# Processing Record 302 for shangrao
# Processing Record 303 for iralaya
# Processing Record 304 for pangnirtung
# Processing Record 305 for camacha
# Processing Record 306 for zugdidi
# Processing Record 307 for chatakonda
# Processing Record 308 for kenai
# Processing Record 309 for sept-iles
# City not found, skipping
# City not found, skipping
# Processing Record 310 for high level
# Processing Record 311 for lagoa
# City not found, skipping
# Processing Record 312 for rundu
# Processing Record 313 for itarema
# Processing Record 314 for cartagena
# Processing Record 315 for salinopolis
# Processing Record 316 for yantongshan
# Processing Record 317 for leesburg
# Processing Record 318 for canning
# Processing Record 319 for saint-pierre
# City not found, skipping
# City not found, skipping
# Processing Record 320 for gimli
# Processing Record 321 for natal
# Processing Record 322 for palamos
# City not found, skipping
# City not found, skipping
# Processing Record 323 for muros
# Processing Record 324 for plattsburgh
# Processing Record 325 for adrar
# Processing Record 326 for cabot
# Processing Record 327 for iqaluit
# City not found, skipping
# Processing Record 328 for saint-georges
# Processing Record 329 for leningradskiy
# Processing Record 330 for vao
# Processing Record 331 for ponta do sol
# Processing Record 332 for phon
# Processing Record 333 for sorland
# City not found, skipping
# Processing Record 334 for maine-soroa
# Processing Record 335 for grindavik
# Processing Record 336 for abai
# Processing Record 337 for illela
# Processing Record 338 for esperance
# Processing Record 339 for obo
# Processing Record 340 for chokurdakh
# Processing Record 341 for najran
# Processing Record 342 for shenkursk
# City not found, skipping
# Processing Record 343 for worthing
# Processing Record 344 for kavieng
# Processing Record 345 for kenora
# Processing Record 346 for shelburne
# Processing Record 347 for ayan
# Processing Record 348 for warwick
# Processing Record 349 for half moon bay
# Processing Record 350 for dunedin
# Processing Record 351 for douentza
# Processing Record 352 for norsup
# Processing Record 353 for saint pete beach
# Processing Record 354 for kavaratti
# Processing Record 355 for inongo
# Processing Record 356 for tabou
# Processing Record 357 for avarua
# Processing Record 358 for mount gambier
# Processing Record 359 for owerri
# Processing Record 360 for hovd
# City not found, skipping
# City not found, skipping
# Processing Record 361 for hambantota
# Processing Record 362 for okhotsk
# Processing Record 363 for atikokan
# Processing Record 364 for anchorage
# City not found, skipping
# Processing Record 365 for toamasina
# Processing Record 366 for tessaoua
# Processing Record 367 for neustadt
# Processing Record 368 for samarai
# Processing Record 369 for saint-paul
# Processing Record 370 for sao paulo de olivenca
# Processing Record 371 for pisco
# Processing Record 372 for strandby
# City not found, skipping
# Processing Record 373 for plettenberg bay
# Processing Record 374 for nizhniy ingash
# Processing Record 375 for zyryanka
# Processing Record 376 for shamgarh
# Processing Record 377 for meulaboh
# Processing Record 378 for dakar
# Processing Record 379 for padang
# Processing Record 380 for shingu
# Processing Record 381 for sorong
# Processing Record 382 for waddan
# Processing Record 383 for montague
# Processing Record 384 for mednogorsk
# Processing Record 385 for mikhaylovka
# Processing Record 386 for challapata
# Processing Record 387 for san patricio
# Processing Record 388 for pec
# Processing Record 389 for moose factory
# Processing Record 390 for gizo
# City not found, skipping
# Processing Record 391 for smithers
# Processing Record 392 for tezu
# City not found, skipping
# City not found, skipping
# Processing Record 393 for mufulira
# Processing Record 394 for taltal
# Processing Record 395 for alpena
# Processing Record 396 for yar-sale
# Processing Record 397 for tuatapere
# City not found, skipping
# Processing Record 398 for orel
# Processing Record 399 for constantine
# Processing Record 400 for shasta lake
# Processing Record 401 for panchgani
# Processing Record 402 for wamba
# Processing Record 403 for la orilla
# Processing Record 404 for boffa
# Processing Record 405 for ahuimanu
# Processing Record 406 for belyy yar
# Processing Record 407 for husavik
# Processing Record 408 for upington
# Processing Record 409 for swan river
# Processing Record 410 for saint-joseph
# Processing Record 411 for kigorobya
# Processing Record 412 for parana
# Processing Record 413 for skibbereen
# Processing Record 414 for rabaul
# Processing Record 415 for luderitz
# Processing Record 416 for aberdeen
# Processing Record 417 for rio das pedras
# Processing Record 418 for boddam
# Processing Record 419 for kieta
# Processing Record 420 for marabba
# Processing Record 421 for makat
# Processing Record 422 for inuvik
# Processing Record 423 for berlevag
# Processing Record 424 for ixtapa
# Processing Record 425 for nhulunbuy
# Processing Record 426 for ossora
# Processing Record 427 for ulaanbaatar
# Processing Record 428 for omboue
# Processing Record 429 for egvekinot
# Processing Record 430 for kailua
# City not found, skipping
# Processing Record 431 for antsohihy
# Processing Record 432 for geraldton
# Processing Record 433 for narsaq
# Processing Record 434 for hervey bay
# Processing Record 435 for karratha
# Processing Record 436 for bhakkar
# Processing Record 437 for rincon
# Processing Record 438 for riyadh
# Processing Record 439 for santa isabel
# Processing Record 440 for petropavlovsk-kamchatskiy
# Processing Record 441 for turbat
# Processing Record 442 for gold coast
# Processing Record 443 for arman
# Processing Record 444 for svetlogorsk
# Processing Record 445 for watsa
# Processing Record 446 for takaungu
# Processing Record 447 for jiuquan
# Processing Record 448 for rio gallegos
# Processing Record 449 for were ilu
# Processing Record 450 for yakeshi
# Processing Record 451 for mehamn
# Processing Record 452 for kouqian
# Processing Record 453 for nekrasovskoye
# Processing Record 454 for kandrian
# Processing Record 455 for peace river
# Processing Record 456 for pochutla
# City not found, skipping
# Processing Record 457 for badiraguato
# Processing Record 458 for kikwit
# Processing Record 459 for alyangula
# City not found, skipping
# Processing Record 460 for zwedru
# Processing Record 461 for oneonta
# Processing Record 462 for harper
# Processing Record 463 for arawa
# Processing Record 464 for la ronge
# Processing Record 465 for bordighera
# Processing Record 466 for coihaique
# Processing Record 467 for havre-saint-pierre
# Processing Record 468 for le vauclin
# Processing Record 469 for santa cruz
# City not found, skipping
# Processing Record 470 for hay river
# Processing Record 471 for burnie
# Processing Record 472 for sumbe
# Processing Record 473 for bridlington
# Processing Record 474 for pietermaritzburg
# Processing Record 475 for oranjemund
# Processing Record 476 for artigas
# Processing Record 477 for pokhara
# Processing Record 478 for pastavy
# Processing Record 479 for pacific grove
# Processing Record 480 for manokwari
# Processing Record 481 for oistins
# Processing Record 482 for goure
# Processing Record 483 for sao joao da barra
# Processing Record 484 for postoloprty
# Processing Record 485 for kysyl-syr
# Processing Record 486 for kiruna
# Processing Record 487 for oktyabrskiy
# Processing Record 488 for general roca
# Processing Record 489 for boa vista
# Processing Record 490 for ambilobe
# Processing Record 491 for aksu
# Processing Record 492 for grand-santi
# Processing Record 493 for tilichiki
# Processing Record 494 for bria
# Processing Record 495 for linjiang
# Processing Record 496 for ancud
# City not found, skipping
# Processing Record 497 for sokoni
# Processing Record 498 for katakwi
# Processing Record 499 for kinablangan
# Processing Record 500 for hassan
# City not found, skipping
# Processing Record 501 for kalmunai
# Processing Record 502 for tenenkou
# Processing Record 503 for charters towers
# City not found, skipping
# Processing Record 504 for male
# Processing Record 505 for tecoman
# Processing Record 506 for chapais
# Processing Record 507 for sao miguel do araguaia
# Processing Record 508 for progreso
# Processing Record 509 for kahuta
# Processing Record 510 for bam
# City not found, skipping
# City not found, skipping
# Processing Record 511 for ahipara
# Processing Record 512 for poronaysk
# Processing Record 513 for san juan
# Processing Record 514 for lasa
# Processing Record 515 for tremosna
# Processing Record 516 for beyneu
# Processing Record 517 for gobabis
# Processing Record 518 for mwense
# Processing Record 519 for maracaibo
# Processing Record 520 for karoi
# Processing Record 521 for baykit
# Processing Record 522 for guasdualito
# Processing Record 523 for xacmaz
# Processing Record 524 for miraflores
# City not found, skipping
# Processing Record 525 for finschhafen
# Processing Record 526 for nantucket
# Processing Record 527 for sola
# Processing Record 528 for hailar
# Processing Record 529 for athabasca
# Processing Record 530 for walvis bay
# Processing Record 531 for ponta delgada
# Processing Record 532 for kupang
# Processing Record 533 for pemba
# City not found, skipping
# Processing Record 534 for hofn
# Processing Record 535 for biak
# Processing Record 536 for nyimba
# Processing Record 537 for sinnamary
# Processing Record 538 for victor harbor
# Processing Record 539 for ziyang
# Processing Record 540 for colesberg
# Processing Record 541 for quatre cocos
# Processing Record 542 for novosergiyevka
# City not found, skipping
# Processing Record 543 for tolga
# Processing Record 544 for eyl
# Processing Record 545 for lady frere
# Processing Record 546 for mount isa
# Processing Record 547 for swan hill
# Processing Record 548 for atchison
# Processing Record 549 for san cristobal
# Processing Record 550 for mogadishu
# Processing Record 551 for misratah
# Processing Record 552 for port keats
# Processing Record 553 for jintur
# Processing Record 554 for rzeszow
# Processing Record 555 for newport
# Processing Record 556 for port hedland

# %%
# Create dataframe of data collecting through the API calls
data = pd.DataFrame(
    {'City': citi,
    'Cloud Cover': cloud,
    'Country': country,
    'Humidity': humid,
    'Latitude': lat,
    'Longitude': lng,
    'Temperature': temp,
    'Wind Speed': wind})

#merge the dataframe from the API calls with the continent dataframe to add a column with the continent value.
data2=data.merge(cont, on='Country', how='left')
data2.to_csv(outputfile)
data2.head()
# Out:
#             City  Cloud Cover Country  Humidity  Latitude  Longitude  \
# 0  Sioux Lookout           75      CA        35     50.10     -91.92
# 1         Celles           92      FR        87     45.61      -0.37
# 2         Beloha            0      MG        88    -25.17      45.06
# 3     Nikolskoye            0      RU        68     59.70      30.79
# 4        Ushuaia           75      AR        75    -54.81     -68.31
#
#    Temperature  Wind Speed Continent
# 0        26.60       18.34        NA
# 1        45.00        8.05        EU
# 2        63.93        3.60        AF
# 3        32.00        2.24        EU
# 4        42.80       21.92        SA

# %%
# This dictionary will allow us to map different continents to different colors in the plot. It's fun!
colors = {'NA': 'r', 'SA': 'b', 'AS': 'g', 'AF': 'purple', 'EU': 'orange', 'OC': 'yellow', 'AN': 'black'}

#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2.Temperature, color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red',label='North America')
SA = mpatches.Patch(color='blue', label='South America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Max Temperature on {date}")
plt.xlabel("Latitude")
plt.ylabel("Max Tempertaure (F)")
plt.xlim([-90,90])
plt.ylim([-30,110])

#Save the image to a file
plt.savefig('output/Temp.png')

# %%
#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2.Humidity, color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red', label='N. America')
SA = mpatches.Patch(color='blue', label='S. America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Humidity on {date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim([-90,90])
plt.ylim([0,105])

#Save the image to a file
plt.savefig('output/Humidity.png')

# %%
#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2['Cloud Cover'], color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red',label='N. America')
SA = mpatches.Patch(color='blue', label='S. America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Cloud Cover on {date}")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")
plt.xlim([-90,90])
plt.ylim([-5,105])

#Save the image to a file
plt.savefig('output/Clouds.png')

# %%
#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2['Wind Speed'], color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red',label='North America')
SA = mpatches.Patch(color='blue', label='South America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Wind Speed on {date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
plt.xlim([-90,90])
plt.ylim([-2.5,50])

#Save the image to a file
plt.savefig('output/Wind.png')
