# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * It is very apparent in this data that the latitude is very strongly correlated with the max temperature in any given city. More specifically, there is a positive correlation between the absolute value of the latitude and the max temperature, meaning as you get further away from the equator, the max temperature increases.
# * There seems to be no particular relationship between city latitude and Humidity, with the exception of a dearth of low humidity cities within 20 degrees of the equator. Once you get 20 degrees north or south of the equator, the range of humidity ranges from 40 percent to 100 percent without a strong relationship between latitude and humidity.
# * Continents do not seem to very strongly correlate with any of the factors tested here, with the exception of the relationships that already exist with Latitude.
# * The data collected for clou cover is discrete, rather than continuous, and as such, it is not clear that the data would demonstrate as strong a relationship as the other factors might. In any case, the data presented do not seem to correlate between cloud cover and latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.font_manager import FontProperties
import pandas as pd
import numpy as np
import requests
import datetime
import time
from pprint import pprint

#Import Date of Pull
now =datetime.datetime.now()
date = now.strftime("%m/%d/%Y")

# Import API key
from api_keys import api_key as key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
outputfile = "output/cities.csv"

#Import continent converting csv and make datafram. 
#This will allow the continents to be displayed in different colors on the graph
cont = pd.read_csv("continent.csv", keep_default_na=False)
cont = cont.rename(index=str, columns={'iso 3166 country':'Country', 'continent code': 'Continent'})

# define units as imperial
units = 'imperial'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
pprint(len(cities))
# Out:
# 611

# %%
#Define the base query url
qurl = "http://api.openweathermap.org/data/2.5/weather?appid=" + key + "&units=" + units + "&q="
# define lists for the variables tracked and the counter for the record count
humid = []
cloud =[]
wind = []
lat = []
lng = []
temp = []
citi = []
country = []
count = 1

# Loop through the city list and collect the variables needed.
# Also add the Error processing to print that it is skipping a city.
for city in cities:
    try:
        resp = requests.get(qurl + city).json()
        lat.append(resp['coord']['lat'])
        lng.append(resp['coord']['lon'])
        temp.append(resp['main']['temp_max'])
        humid.append(resp['main']['humidity'])
        cloud.append(resp['clouds']['all'])
        wind.append(resp['wind']['speed'])
        citi.append(resp['name'])
        country.append(resp['sys']['country'])
        print(f"Processing Record {count} for {city}")
        count = count + 1
    except KeyError:
        print("City not found, skipping")
        continue
# This delay line is probably unnecessary, but it is included so that the API doesn't get locked out.    
    time.sleep(.01)
# Out:
# Processing Record 1 for puerto ayora
# Processing Record 2 for arraial do cabo
# Processing Record 3 for saskylakh
# Processing Record 4 for verkhnyaya inta
# Processing Record 5 for kapaa
# Processing Record 6 for ushuaia
# Processing Record 7 for cairns
# Processing Record 8 for fairbanks
# Processing Record 9 for cabo san lucas
# City not found, skipping
# Processing Record 10 for esik
# Processing Record 11 for thompson
# Processing Record 12 for yelizovo
# City not found, skipping
# Processing Record 13 for dikson
# Processing Record 14 for upernavik
# Processing Record 15 for bijbiara
# Processing Record 16 for hithadhoo
# Processing Record 17 for punta arenas
# Processing Record 18 for baherden
# Processing Record 19 for san jose
# Processing Record 20 for cape town
# Processing Record 21 for saldanha
# Processing Record 22 for amurzet
# Processing Record 23 for rikitea
# Processing Record 24 for vaini
# Processing Record 25 for bethel
# Processing Record 26 for petropavlovsk-kamchatskiy
# Processing Record 27 for beeville
# Processing Record 28 for saint-philippe
# City not found, skipping
# Processing Record 29 for gravdal
# Processing Record 30 for hobart
# Processing Record 31 for leningradskiy
# Processing Record 32 for lebu
# Processing Record 33 for hermanus
# Processing Record 34 for nikolskoye
# City not found, skipping
# Processing Record 35 for goulburn
# Processing Record 36 for kavieng
# Processing Record 37 for quatre cocos
# Processing Record 38 for iralaya
# Processing Record 39 for pisco
# Processing Record 40 for bredasdorp
# City not found, skipping
# Processing Record 41 for kodiak
# Processing Record 42 for mataura
# Processing Record 43 for magdagachi
# Processing Record 44 for grindavik
# Processing Record 45 for olinda
# Processing Record 46 for cidreira
# Processing Record 47 for tuktoyaktuk
# Processing Record 48 for sokolow podlaski
# City not found, skipping
# Processing Record 49 for pevek
# Processing Record 50 for lompoc
# Processing Record 51 for hambantota
# Processing Record 52 for lazaro cardenas
# Processing Record 53 for saint-joseph
# Processing Record 54 for alice springs
# Processing Record 55 for phangnga
# Processing Record 56 for ucluelet
# Processing Record 57 for the valley
# Processing Record 58 for eureka
# Processing Record 59 for butaritari
# City not found, skipping
# Processing Record 60 for port augusta
# Processing Record 61 for beloha
# Processing Record 62 for kaitangata
# Processing Record 63 for yellowknife
# Processing Record 64 for birin
# City not found, skipping
# Processing Record 65 for mahebourg
# Processing Record 66 for vostok
# City not found, skipping
# Processing Record 67 for constantine
# Processing Record 68 for sitka
# Processing Record 69 for east london
# City not found, skipping
# Processing Record 70 for ayan
# Processing Record 71 for jamestown
# Processing Record 72 for albany
# Processing Record 73 for sao caetano de odivelas
# Processing Record 74 for roma
# Processing Record 75 for chuy
# Processing Record 76 for anloga
# Processing Record 77 for namatanai
# Processing Record 78 for blackwater
# Processing Record 79 for tuatapere
# Processing Record 80 for caravelas
# Processing Record 81 for dingle
# Processing Record 82 for aklavik
# Processing Record 83 for castro
# Processing Record 84 for georgetown
# City not found, skipping
# Processing Record 85 for damietta
# City not found, skipping
# City not found, skipping
# Processing Record 86 for hidalgotitlan
# Processing Record 87 for maniitsoq
# City not found, skipping
# City not found, skipping
# Processing Record 88 for barrow
# Processing Record 89 for norman wells
# City not found, skipping
# Processing Record 90 for lorengau
# Processing Record 91 for shimoda
# Processing Record 92 for san cristobal
# Processing Record 93 for severo-kurilsk
# Processing Record 94 for husavik
# Processing Record 95 for gamba
# Processing Record 96 for guerrero negro
# Processing Record 97 for sinnamary
# Processing Record 98 for bonavista
# Processing Record 99 for kihurio
# Processing Record 100 for new norfolk
# Processing Record 101 for busselton
# Processing Record 102 for mar del plata
# Processing Record 103 for atuona
# Processing Record 104 for diapaga
# Processing Record 105 for inongo
# Processing Record 106 for kidal
# Processing Record 107 for manokwari
# City not found, skipping
# Processing Record 108 for port keats
# Processing Record 109 for inhambane
# Processing Record 110 for qaqortoq
# Processing Record 111 for sibu
# Processing Record 112 for yumen
# Processing Record 113 for tongzi
# Processing Record 114 for ketchikan
# City not found, skipping
# Processing Record 115 for ribeira grande
# Processing Record 116 for puerto madryn
# Processing Record 117 for chanthaburi
# Processing Record 118 for taoudenni
# Processing Record 119 for tarata
# Processing Record 120 for garwa
# Processing Record 121 for zanjan
# Processing Record 122 for rongcheng
# Processing Record 123 for puerto leguizamo
# Processing Record 124 for richards bay
# City not found, skipping
# Processing Record 125 for kristiansund
# Processing Record 126 for antalaha
# Processing Record 127 for khatanga
# Processing Record 128 for san patricio
# Processing Record 129 for karratha
# Processing Record 130 for tilichiki
# Processing Record 131 for ilulissat
# Processing Record 132 for cardston
# Processing Record 133 for maragogi
# Processing Record 134 for kamskoye ustye
# Processing Record 135 for vardo
# Processing Record 136 for bubaque
# Processing Record 137 for murray bridge
# Processing Record 138 for provideniya
# Processing Record 139 for huayang
# Processing Record 140 for mareeba
# Processing Record 141 for souillac
# Processing Record 142 for grand gaube
# Processing Record 143 for esperance
# Processing Record 144 for constitucion
# Processing Record 145 for kununurra
# Processing Record 146 for aranos
# Processing Record 147 for srednekolymsk
# Processing Record 148 for chokurdakh
# Processing Record 149 for puerto ayacucho
# Processing Record 150 for klaksvik
# Processing Record 151 for tateyama
# City not found, skipping
# Processing Record 152 for shenavan
# Processing Record 153 for teguldet
# Processing Record 154 for bluff
# Processing Record 155 for villa constitucion
# Processing Record 156 for port alfred
# Processing Record 157 for bambous virieux
# City not found, skipping
# City not found, skipping
# Processing Record 158 for cherskiy
# Processing Record 159 for adre
# Processing Record 160 for avarua
# Processing Record 161 for sambava
# Processing Record 162 for churapcha
# City not found, skipping
# Processing Record 163 for falmouth
# Processing Record 164 for antofagasta
# Processing Record 165 for tual
# Processing Record 166 for hilo
# City not found, skipping
# Processing Record 167 for dzilam gonzalez
# Processing Record 168 for kholmogory
# City not found, skipping
# Processing Record 169 for lucea
# Processing Record 170 for heishan
# Processing Record 171 for gornyy
# Processing Record 172 for victor harbor
# Processing Record 173 for los llanos de aridane
# Processing Record 174 for qaanaaq
# Processing Record 175 for san juan sacatepequez
# Processing Record 176 for mount isa
# Processing Record 177 for tarma
# Processing Record 178 for bathsheba
# Processing Record 179 for ariquemes
# Processing Record 180 for susanville
# Processing Record 181 for iqaluit
# Processing Record 182 for hun
# Processing Record 183 for masterton
# Processing Record 184 for clyde river
# Processing Record 185 for hokitika
# Processing Record 186 for ilhabela
# Processing Record 187 for rocha
# Processing Record 188 for alta floresta
# Processing Record 189 for santa maria
# Processing Record 190 for kostomuksha
# Processing Record 191 for carnarvon
# City not found, skipping
# Processing Record 192 for parkes
# Processing Record 193 for mana
# Processing Record 194 for mezen
# Processing Record 195 for khairpur nathan shah
# Processing Record 196 for pavlovo
# Processing Record 197 for rio grande
# Processing Record 198 for dwarka
# Processing Record 199 for torbay
# Processing Record 200 for longyearbyen
# Processing Record 201 for vao
# Processing Record 202 for zhezkazgan
# Processing Record 203 for boguchany
# Processing Record 204 for avera
# Processing Record 205 for hami
# Processing Record 206 for buin
# Processing Record 207 for talnakh
# Processing Record 208 for jalingo
# Processing Record 209 for fort saint james
# Processing Record 210 for tigzirt
# Processing Record 211 for puerto del rosario
# Processing Record 212 for lavrentiya
# Processing Record 213 for omboue
# Processing Record 214 for ancud
# Processing Record 215 for cabinda
# Processing Record 216 for thinadhoo
# City not found, skipping
# Processing Record 217 for amga
# Processing Record 218 for praya
# Processing Record 219 for college
# Processing Record 220 for lac du bonnet
# Processing Record 221 for ko samui
# Processing Record 222 for strezhevoy
# Processing Record 223 for neiafu
# Processing Record 224 for idrinskoye
# Processing Record 225 for faanui
# Processing Record 226 for qasigiannguit
# Processing Record 227 for tak bai
# Processing Record 228 for phek
# City not found, skipping
# Processing Record 229 for khandyga
# Processing Record 230 for portland
# Processing Record 231 for okha
# City not found, skipping
# Processing Record 232 for harper
# Processing Record 233 for ekhabi
# Processing Record 234 for shihezi
# Processing Record 235 for lata
# Processing Record 236 for labuan
# City not found, skipping
# Processing Record 237 for horqueta
# City not found, skipping
# Processing Record 238 for sorland
# Processing Record 239 for miles city
# Processing Record 240 for flin flon
# Processing Record 241 for lardos
# City not found, skipping
# Processing Record 242 for mweka
# Processing Record 243 for tambovka
# Processing Record 244 for tucano
# Processing Record 245 for sao jose da coroa grande
# City not found, skipping
# Processing Record 246 for vestmannaeyjar
# Processing Record 247 for salinopolis
# Processing Record 248 for wanlaweyn
# Processing Record 249 for kutum
# Processing Record 250 for sirsi
# Processing Record 251 for hofn
# Processing Record 252 for ilo
# Processing Record 253 for huambo
# City not found, skipping
# City not found, skipping
# Processing Record 254 for bandarbeyla
# City not found, skipping
# Processing Record 255 for saint anthony
# Processing Record 256 for la asuncion
# Processing Record 257 for iquique
# Processing Record 258 for rizhao
# Processing Record 259 for port elizabeth
# Processing Record 260 for doha
# Processing Record 261 for byron bay
# Processing Record 262 for kurush
# Processing Record 263 for luderitz
# City not found, skipping
# Processing Record 264 for mount hagen
# Processing Record 265 for magistralnyy
# Processing Record 266 for pangnirtung
# City not found, skipping
# Processing Record 267 for horana
# Processing Record 268 for vila franca do campo
# Processing Record 269 for saint-augustin
# Processing Record 270 for salcininkai
# Processing Record 271 for tasiilaq
# Processing Record 272 for shirpur
# Processing Record 273 for mongo
# Processing Record 274 for masiga
# Processing Record 275 for yulara
# Processing Record 276 for ust-omchug
# Processing Record 277 for carmignano
# Processing Record 278 for yerbogachen
# City not found, skipping
# Processing Record 279 for palora
# Processing Record 280 for kozhva
# City not found, skipping
# Processing Record 281 for conceicao do araguaia
# Processing Record 282 for fort-shevchenko
# Processing Record 283 for tabuk
# Processing Record 284 for seoul
# Processing Record 285 for mawlaik
# Processing Record 286 for ewa beach
# City not found, skipping
# Processing Record 287 for pimentel
# Processing Record 288 for sobolevo
# Processing Record 289 for villa maria
# Processing Record 290 for marsa matruh
# Processing Record 291 for buenavista
# Processing Record 292 for bukoba
# City not found, skipping
# Processing Record 293 for agadir
# Processing Record 294 for agadez
# Processing Record 295 for hvide sande
# Processing Record 296 for takoradi
# Processing Record 297 for scarborough
# Processing Record 298 for wangqing
# Processing Record 299 for salalah
# Processing Record 300 for ushtobe
# Processing Record 301 for mount gambier
# Processing Record 302 for shakawe
# Processing Record 303 for empalme
# Processing Record 304 for florianopolis
# Processing Record 305 for alyangula
# Processing Record 306 for sabha
# Processing Record 307 for thunder bay
# Processing Record 308 for bilibino
# Processing Record 309 for viedma
# Processing Record 310 for russell
# Processing Record 311 for geraldton
# Processing Record 312 for srandakan
# City not found, skipping
# Processing Record 313 for wairoa
# Processing Record 314 for finschhafen
# Processing Record 315 for jimo
# City not found, skipping
# Processing Record 316 for luwuk
# City not found, skipping
# Processing Record 317 for dunyapur
# Processing Record 318 for narsaq
# Processing Record 319 for tiksi
# Processing Record 320 for natal
# Processing Record 321 for inuvik
# Processing Record 322 for shelburne
# Processing Record 323 for marawi
# Processing Record 324 for mahajanga
# Processing Record 325 for ormara
# Processing Record 326 for ilebo
# City not found, skipping
# Processing Record 327 for zharkovskiy
# Processing Record 328 for spirit river
# Processing Record 329 for roanoke rapids
# Processing Record 330 for jiayuguan
# Processing Record 331 for nisia floresta
# City not found, skipping
# Processing Record 332 for naze
# Processing Record 333 for lazi
# Processing Record 334 for keti bandar
# Processing Record 335 for chancay
# Processing Record 336 for puerto escondido
# Processing Record 337 for hovd
# City not found, skipping
# Processing Record 338 for dunmore east
# Processing Record 339 for yenagoa
# Processing Record 340 for kavaratti
# Processing Record 341 for usinsk
# Processing Record 342 for nosy varika
# Processing Record 343 for praia
# Processing Record 344 for bambanglipuro
# Processing Record 345 for ixtapa
# Processing Record 346 for colares
# Processing Record 347 for ahipara
# Processing Record 348 for lubao
# Processing Record 349 for bissau
# Processing Record 350 for siverek
# Processing Record 351 for canmore
# Processing Record 352 for valparaiso
# Processing Record 353 for nanakuli
# Processing Record 354 for lagoa
# City not found, skipping
# Processing Record 355 for brooks
# Processing Record 356 for sovetskaya gavan
# Processing Record 357 for paciran
# Processing Record 358 for kahului
# Processing Record 359 for numan
# Processing Record 360 for jesup
# Processing Record 361 for lamont
# Processing Record 362 for broome
# Processing Record 363 for anadyr
# Processing Record 364 for charyshskoye
# Processing Record 365 for tessalit
# Processing Record 366 for victoria
# Processing Record 367 for coquimbo
# Processing Record 368 for ranau
# Processing Record 369 for pasni
# Processing Record 370 for dharchula
# City not found, skipping
# Processing Record 371 for gazojak
# Processing Record 372 for nemuro
# Processing Record 373 for cayenne
# Processing Record 374 for aykhal
# Processing Record 375 for alot
# Processing Record 376 for namalenga
# Processing Record 377 for kearney
# City not found, skipping
# Processing Record 378 for beringovskiy
# Processing Record 379 for kailua
# Processing Record 380 for hobyo
# Processing Record 381 for saint george
# Processing Record 382 for parabel
# Processing Record 383 for metro
# Processing Record 384 for vuktyl
# Processing Record 385 for svetlaya
# Processing Record 386 for vila velha
# Processing Record 387 for faya
# Processing Record 388 for tezu
# City not found, skipping
# Processing Record 389 for sikasso
# Processing Record 390 for maura
# City not found, skipping
# Processing Record 391 for adrar
# Processing Record 392 for joshimath
# Processing Record 393 for egvekinot
# Processing Record 394 for matale
# Processing Record 395 for dudinka
# Processing Record 396 for aleksandrovka
# Processing Record 397 for okhotsk
# Processing Record 398 for hearst
# Processing Record 399 for sault sainte marie
# Processing Record 400 for opuwo
# Processing Record 401 for santa rosa
# Processing Record 402 for minggang
# Processing Record 403 for awbari
# Processing Record 404 for duku
# City not found, skipping
# Processing Record 405 for berezovyy
# City not found, skipping
# Processing Record 406 for christchurch
# Processing Record 407 for japura
# Processing Record 408 for yagodnoye
# Processing Record 409 for teya
# Processing Record 410 for manta
# Processing Record 411 for abonnema
# Processing Record 412 for koutiala
# Processing Record 413 for raudeberg
# Processing Record 414 for port hedland
# Processing Record 415 for lavumisa
# Processing Record 416 for el hatillo
# Processing Record 417 for igmaya-an
# Processing Record 418 for koslan
# Processing Record 419 for agutaya
# Processing Record 420 for bira
# Processing Record 421 for hualmay
# Processing Record 422 for sioux lookout
# Processing Record 423 for coahuayana
# City not found, skipping
# Processing Record 424 for prabumulih
# Processing Record 425 for kathmandu
# Processing Record 426 for haines junction
# Processing Record 427 for friockheim
# Processing Record 428 for san andres
# Processing Record 429 for ngorongoro
# Processing Record 430 for quelimane
# Processing Record 431 for tucupita
# Processing Record 432 for komsomolskiy
# Processing Record 433 for pabrade
# Processing Record 434 for varhaug
# Processing Record 435 for barra do garcas
# Processing Record 436 for sao filipe
# Processing Record 437 for upata
# Processing Record 438 for general pico
# Processing Record 439 for agboville
# Processing Record 440 for kulhudhuffushi
# Processing Record 441 for koppal
# Processing Record 442 for mayo
# Processing Record 443 for manggar
# Processing Record 444 for lensk
# Processing Record 445 for ostrovnoy
# City not found, skipping
# Processing Record 446 for pinega
# City not found, skipping
# Processing Record 447 for tupik
# Processing Record 448 for great falls
# Processing Record 449 for sarlat-la-caneda
# Processing Record 450 for kirakira
# Processing Record 451 for reims
# Processing Record 452 for genhe
# Processing Record 453 for berlevag
# Processing Record 454 for northam
# City not found, skipping
# Processing Record 455 for rafaela
# Processing Record 456 for mackay
# City not found, skipping
# City not found, skipping
# Processing Record 457 for palu
# Processing Record 458 for paamiut
# Processing Record 459 for fernie
# City not found, skipping
# Processing Record 460 for rio cuarto
# Processing Record 461 for necochea
# Processing Record 462 for kupang
# Processing Record 463 for mahibadhoo
# Processing Record 464 for brae
# Processing Record 465 for mercedes
# Processing Record 466 for xining
# Processing Record 467 for basco
# Processing Record 468 for merauke
# City not found, skipping
# Processing Record 469 for angoche
# Processing Record 470 for poya
# Processing Record 471 for lakshettipet
# Processing Record 472 for udachnyy
# Processing Record 473 for kysyl-syr
# Processing Record 474 for san quintin
# Processing Record 475 for bara
# Processing Record 476 for sikonge
# Processing Record 477 for miri
# Processing Record 478 for vallenar
# Processing Record 479 for vangaindrano
# Processing Record 480 for nizhniy tagil
# Processing Record 481 for knysna
# Processing Record 482 for zyryanka
# Processing Record 483 for eidsvoll
# Processing Record 484 for gualaquiza
# Processing Record 485 for ostersund
# Processing Record 486 for tanete
# Processing Record 487 for iskateley
# Processing Record 488 for kruisfontein
# Processing Record 489 for grahamstown
# Processing Record 490 for bucovice
# Processing Record 491 for porto novo
# Processing Record 492 for winnemucca
# Processing Record 493 for salamanca
# Processing Record 494 for nieves
# Processing Record 495 for collierville
# Processing Record 496 for grande prairie
# Processing Record 497 for loukhi
# City not found, skipping
# Processing Record 498 for ponta do sol
# Processing Record 499 for lixourion
# Processing Record 500 for verkhoturye
# Processing Record 501 for uberaba
# Processing Record 502 for tiarei
# Processing Record 503 for saint-pierre
# Processing Record 504 for port lincoln
# Processing Record 505 for delijan
# Processing Record 506 for eyl
# Processing Record 507 for boshnyakovo
# Processing Record 508 for zlobin
# Processing Record 509 for acapulco
# Processing Record 510 for bay city
# Processing Record 511 for coihaique
# Processing Record 512 for nagua
# Processing Record 513 for san fernando
# Processing Record 514 for namibe
# Processing Record 515 for nantucket
# Processing Record 516 for san rafael
# Processing Record 517 for grants
# Processing Record 518 for ladario
# City not found, skipping
# Processing Record 519 for praia da vitoria
# Processing Record 520 for jinchang
# Processing Record 521 for canguaretama
# Processing Record 522 for khani
# Processing Record 523 for codrington
# Processing Record 524 for vestmanna
# Processing Record 525 for lebork
# Processing Record 526 for kaeo
# Processing Record 527 for zhengjiatun
# Processing Record 528 for petropavl
# Processing Record 529 for lohardaga
# Processing Record 530 for mount pleasant
# Processing Record 531 for griffith
# City not found, skipping
# Processing Record 532 for san jeronimo
# Processing Record 533 for middelburg
# Processing Record 534 for terny
# Processing Record 535 for port hardy
# Processing Record 536 for matiguas
# Processing Record 537 for igarka
# Processing Record 538 for kasangulu
# Processing Record 539 for hasaki
# Processing Record 540 for pontes e lacerda
# Processing Record 541 for floro
# Processing Record 542 for atyrau
# Processing Record 543 for nouadhibou
# Processing Record 544 for dunda
# Processing Record 545 for kavali

# %%
# Create dataframe of data collecting through the API calls
data = pd.DataFrame(
    {'City': citi,
    'Cloud Cover': cloud,
    'Country': country,
    'Humidity': humid,
    'Latitude': lat,
    'Longitude': lng,
    'Temperature': temp,
    'Wind Speed': wind})

#merge the dataframe from the API calls with the continent dataframe to add a column with the continent value.
data2=data.merge(cont, on='Country', how='left')
data2.to_csv(outputfile)
data2.head()
# Out:
#               City  Cloud Cover Country  Humidity  Latitude  Longitude  \
# 0     Puerto Ayora           92      EC        95     -0.74     -90.35
# 1  Arraial do Cabo            0      BR        90    -22.97     -42.02
# 2        Saskylakh            0      RU        90     71.97     114.09
# 3  Verkhnyaya Inta           92      RU        86     65.99      60.32
# 4            Kapaa           40      US        57     22.08    -159.32
#
#    Temperature  Wind Speed Continent
# 0        73.99        1.01        SA
# 1        78.53       19.26        SA
# 2        16.70        8.75        EU
# 3        33.53        9.98        EU
# 4        80.60        8.05        NA

# %%
# This dictionary will allow us to map different continents to different colors in the plot. It's fun!
colors = {'NA': 'r', 'SA': 'b', 'AS': 'g', 'AF': 'purple', 'EU': 'orange', 'OC': 'yellow', 'AN': 'black'}

#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2.Temperature, color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red',label='North America')
SA = mpatches.Patch(color='blue', label='South America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Max Temperature on {date}")
plt.xlabel("Latitude")
plt.ylabel("Max Tempertaure (F)")
plt.xlim([-90,90])
plt.ylim([-30,110])

#Save the image to a file
plt.savefig('output/Temp.png')

# %%
#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2.Humidity, color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red', label='N. America')
SA = mpatches.Patch(color='blue', label='S. America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Humidity on {date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim([-90,90])
plt.ylim([0,105])

#Save the image to a file
plt.savefig('output/Humidity.png')

# %%
#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2['Cloud Cover'], color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red',label='N. America')
SA = mpatches.Patch(color='blue', label='S. America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Cloud Cover on {date}")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")
plt.xlim([-90,90])
plt.ylim([-5,105])

#Save the image to a file
plt.savefig('output/Clouds.png')

# %%
#Plot the graph and add a mapped list of colors by continent
plt.scatter(data2.Latitude, data2['Wind Speed'], color=list(data2['Continent'].map(colors)))

#Create patches which can be imported to label the legend, since all the data is technically one series
NA = mpatches.Patch(color='red',label='North America')
SA = mpatches.Patch(color='blue', label='South America')
AS = mpatches.Patch(color='green', label='Asia')
AF = mpatches.Patch(color='purple', label='Africa')
EU = mpatches.Patch(color='orange', label='Europe')
OC = mpatches.Patch(color='yellow', label='Oceania')
AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Wind Speed on {date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
plt.xlim([-90,90])
plt.ylim([-2.5,50])

#Save the image to a file
plt.savefig('output/Wind.png')

# %%
#Plot the graph and add a mapped list of colors by continent
cmap = plt.cm.get_cmap('seismic')
plt.scatter(data2.Longitude, data2.Latitude, c=data2.Temperature, cmap=cmap)

#Create patches which can be imported to label the legend, since all the data is technically one series
#NA = mpatches.Patch(color='red',label='North America')
#SA = mpatches.Patch(color='blue', label='South America')
#AS = mpatches.Patch(color='green', label='Asia')
#AF = mpatches.Patch(color='purple', label='Africa')
#EU = mpatches.Patch(color='orange', label='Europe')
#OC = mpatches.Patch(color='yellow', label='Oceania')
#AN = mpatches.Patch(color='black', label='Antarctica')

#Use the patches to create a legend, add titles, labels and plot sizes
#plt.legend(handles=[NA, SA, AS, AF, EU, OC, AN], prop={'size': 8})
plt.title(f"City Latitude vs Wind Speed on {date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
plt.xlim([-180,180])
plt.ylim([-90,90])

#Save the image to a file
#plt.savefig('output/Wind.png')
# Out:
# (-90, 90)
